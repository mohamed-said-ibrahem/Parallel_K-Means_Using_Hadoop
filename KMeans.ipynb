# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.cluster import KMeans

# %%
df = pd.read_csv('http://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data', header=None)

# %%
x = df.iloc[:, [0, 1, 2, 3]].values
wcss = []
for i in range(1, 11):
    initlize = []
    for j in range(i):
      initlize.append(x[j])
    initlize = np.asarray(initlize)
    kmeans = KMeans(n_clusters=i, init=initlize, max_iter=100, n_init=1)
    kmeans.fit(x)
    wcss.append(kmeans.inertia_)
    
#Plotting the results onto a line graph, allowing us to observe 'The elbow'
plt.plot(range(1, 11), wcss)
plt.xlabel('Number of clusters')
plt.ylabel('WCSS') #within cluster sum of squares
plt.show()

# %%
#Applying kmeans to the dataset / Creating the kmeans classifier
initlize = []
for j in range(2):
  initlize.append(x[j])
initlize = np.asarray(initlize)
kmeans = KMeans(n_clusters=2, init=initlize, max_iter=100, n_init=1)
y_kmeans = kmeans.fit_predict(x)

# %%
#Visualising the clusters
plt.scatter(x[y_kmeans == 0, 0], x[y_kmeans == 0, 1], s = 90, c = 'yellow', label = 'Iris-setosa')
plt.scatter(x[y_kmeans == 1, 0], x[y_kmeans == 1, 1], s = 90, c = 'blue', label = 'Iris-versicolour')
plt.scatter(x[y_kmeans == 2, 0], x[y_kmeans == 2, 1], s = 90, c = 'red', label = 'Iris-virginica')

#Plotting the centroids of the clusters
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:,1], s = 100, c = 'black', label = 'Centroids')
plt.rcParams["figure.figsize"] = (8,6)
plt.legend()

# %%
print('Initial Centroids are')
print(initlize)
# Out:
# Initial Centroids are
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]]

# %%
print('Final Centroids are')
print(kmeans.cluster_centers_)
# Out:
# Final Centroids are
# [[6.30103093 2.88659794 4.95876289 1.69587629]
#  [5.00566038 3.36037736 1.56226415 0.28867925]]
